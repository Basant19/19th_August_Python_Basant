# %%
#link list implemntation 

class Node:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next
    
    def setdata(self, data):
        self.data = data
    
    def getdata(self):
        return self.data
    
    def setnext(self, next):
        self.next = next
    
    def getnext(self):
        return self.next


def traverse(head):
    temp = head 
    while temp:
        print(temp.getdata(), end=" -> ")
        temp = temp.getnext()
    print("None")

# Example usage:
# Create a linked list 1 -> 2 -> 3 -> None
head=Node (10)
node2=Node (15)
node3=Node (30)
node4=Node (12)
node5=Node (4)
node6=Node (9)

head.setnext (node2)
node2.setnext (node3)
node3.setnext (node4)
node4.setnext (node5)
node5.setnext (node6)

print("Original list:")
traverse(head)
# Out:
# Original list:
# 10 -> 15 -> 30 -> 12 -> 4 -> 9 -> None

# %%
'''Problem 1: Reverse a singly linked list.
'''

# %%
#iterative approach
def ireverse(head):
    prevnode, currentnode, nextnode = None, head, head
    while currentnode:
        nextnode = currentnode.getnext()
        currentnode.setnext(prevnode)
        prevnode = currentnode
        currentnode = nextnode
        
    head = prevnode
    return head

def traverse(head):
    temp = head 
    while temp:
        print(temp.getdata(), end=" -> ")
        temp = temp.getnext()
    print("None")

# Example usage:
# Create a linked list 1 -> 2 -> 3 -> None
head=Node (10)
node2=Node (15)
node3=Node (30)
node4=Node (12)
node5=Node (4)
node6=Node (9)

head.setnext (node2)
node2.setnext (node3)
node3.setnext (node4)
node4.setnext (node5)
node5.setnext (node6)


print("Original list:")
traverse(head)

head = ireverse(head)

print("Reversed list:")
traverse(head)
# Out:
# Original list:
# 10 -> 15 -> 30 -> 12 -> 4 -> 9 -> None
# Reversed list:
# 9 -> 4 -> 12 -> 30 -> 15 -> 10 -> None

# %%
#recursive approach
 
def reverserecur (head):
    if head == None or head.getnext() ==None:
        return head
    newnode=reverserecur(head.getnext())
    headnext=head.getnext()
    headnext.setnext(head)
    head.setnext (None)
    return newnode

def traverse(head):
    temp = head 
    while temp:
        print(temp.getdata(), end=" -> ")
        temp = temp.getnext()
    print("None")
    

head=Node (10)
node2=Node (15)
node3=Node (30)
node4=Node (12)
node5=Node (4)
node6=Node (9)

head.setnext (node2)
node2.setnext (node3)
node3.setnext (node4)
node4.setnext (node5)
node5.setnext (node6)


print("Original list:")
traverse(head)

head = reverserecur (head)

print("Reversed list:")
traverse(head)
# Out:
# Original list:
# 10 -> 15 -> 30 -> 12 -> 4 -> 9 -> None
# Reversed list:
# 9 -> 4 -> 12 -> 30 -> 15 -> 10 -> None

# %%
"""Problem 2: Merge two sorted linked lists into one sorted linked list.
"""
class Node:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next
    
    def setdata(self, data):
        self.data = data
    
    def getdata(self):
        return self.data
    
    def setnext(self, next):
        self.next = next
    
    def getnext(self):
        return self.next


def traverse(head):
    temp = head 
    while temp:
        print(temp.getdata(), end=" -> ")
        temp = temp.getnext()
    print("None")



head1 = Node(1)
node2 = Node(1)
node3 = Node(3)
node4 = Node(12)
node5 = Node(40)
node6 = Node(90)

head1.setnext(node2)
node2.setnext(node3)
node3.setnext(node4)
node4.setnext(node5)
node5.setnext(node6)


head2=Node(2)
node2 = Node(1)
node3 = Node(3)
node4 = Node(12)
node5 = Node(40)
node6 = Node(90)

head2.setnext(node2)
node2.setnext(node3)
node3.setnext(node4)
node4.setnext(node5)
node5.setnext(node6)



def mergelist(head1, head2):
    newnode = Node()
    temp = newnode
    
    while head1 and head2:
        if head1.getdata() < head2.getdata():
            temp.setnext(head1)
            head1 = head1.getnext()
        else:
            temp.setnext(head2)
            head2 = head2.getnext()
        temp = temp.getnext()
    
    if head1:
        temp.setnext(head1)
    elif head2:
        temp.setnext(head2)
    
    return newnode.getnext()

head = mergelist (head1, head2)

print("First list:")
traverse(head1)   

print("Second list:")
traverse(head2) 

print("Merged list:")
traverse(head)
# Out:
# First list:
# 1 -> 1 -> 2 -> 1 -> 3 -> 3 -> 12 -> 12 -> 40 -> 40 -> 90 -> 90 -> None
# Second list:
# 2 -> 1 -> 3 -> 3 -> 12 -> 12 -> 40 -> 40 -> 90 -> 90 -> None
# Merged list:
# 1 -> 1 -> 2 -> 1 -> 3 -> 3 -> 12 -> 12 -> 40 -> 40 -> 90 -> 90 -> None

# %%
"""Problem 3: Remove the nth node from the end of a linked list.
"""


def endremove(head,n):
    fast=head
    for i in range (0,n):
        fast=fast.getnext()
    slow=head
    while fast:
        slow=slow.next
        fast=fast.next
        
    if fast == None:
        return head.next
    
    slow=slow.next.next
    
    return head
        
        
head=Node (10)
node2=Node (15)
node3=Node (30)
node4=Node (12)
node5=Node (4)
node6=Node (9)

head.setnext (node2)
node2.setnext (node3)
node3.setnext (node4)
node4.setnext (node5)
node5.setnext (node6)

print("Original list:")
traverse(head) 

nhead=endremove(head,3)
print("deleted list:")
traverse(nhead)
# Out:
# Original list:
# 10 -> 15 -> 30 -> 12 -> 4 -> 9 -> None
# deleted list:
# 15 -> 30 -> 12 -> 4 -> 9 -> None

# %%
"""Find the intersection point of two linked lists."""



def intersectlinklist (head1,head2):
    temp1=head1
    temp2=head2
    while temp1!=temp2:
        temp1=temp1.getnext() if temp1 else head2
        temp2=temp2.getnext() if temp2 else head1
    return temp1

head1 = Node(1)
node1_2 = Node(1)
node1_3 = Node(3)
node1_4 = Node(12)
node1_5 = Node(40)
node1_6 = Node(90)

head1.setnext(node1_2)
node1_2.setnext(node1_3)
node1_3.setnext(node1_4)
node1_4.setnext(node1_5)
node1_5.setnext(node1_6)


head2 = Node(2)
node2_2 = Node(5)
node2_3 = Node(6)
node2_4 = node1_3
node2_5 = Node(40)
node2_6 = Node(80)

head2.setnext(node2_2)
node2_2.setnext(node2_3)
node2_3.setnext(node2_4)
node2_4.setnext(node2_5)
node2_5.setnext(node2_6)

print ("First Link List")
traverse (head1)

print ("Second Link List")
traverse (head2)

intersect= intersectlinklist(head1,head2)
if intersect:
    print ("Intersection found ")
    traverse(intersect)
    
else:
     print ("Intersection not found")
# Out:
# First Link List
# 1 -> 1 -> 3 -> 40 -> 80 -> None
# Second Link List
# 2 -> 5 -> 6 -> 3 -> 40 -> 80 -> None
# Intersection found
# 3 -> 40 -> 80 -> None

# %%
'''Remove duplicate element 
'''

def remove_duplicates(head):
    current = head
    while current and current.getnext():
        if current.getdata() == current.getnext().getdata():
            current.setnext(current.getnext().getnext())
        else:
            current = current.getnext()



head = Node(10)
node2 = Node(15)
node3 = Node(15)
node4 = Node(30)
node5 = Node(30)
node6 = Node(30)

head.setnext(node2)
node2.setnext(node3)
node3.setnext(node4)
node4.setnext(node5)
node5.setnext(node6)

print("Original linked list:")
traverse(head)

remove_duplicates(head)

print("Linked list after removing duplicates:")
traverse(head)
# Out:
# Original linked list:
# 10 -> 15 -> 15 -> 30 -> 30 -> 30 -> None
# Linked list after removing duplicates:
# 10 -> 15 -> 30 -> None

# %%
'''Add two numbers represented by linked lists where each node contains single digit  
'''



def add_two_numbers(l1, l2):
    dummy_head = Node(0)
    current = dummy_head
    carry = 0

    while l1 or l2:
        
        x = l1.data if l1 else 0
        y = l2.data if l2 else 0

       
        total = carry + x + y
        carry = total // 10
        
        
        current.next = Node(total % 10)
        current = current.next

       
        if l1: l1 = l1.next
        if l2: l2 = l2.next

   
    if carry > 0:
        current.next = Node(carry)

    return dummy_head.next

def print_linked_list(node):
    while node:
        print(node.data, end=" -> " if node.next else "\n")
        node = node.next


l1 = Node(2)
l1.next = Node(4)
l1.next.next = Node(3)


l2 = Node(5)
l2.next = Node(6)
l2.next.next = Node(4)


result = add_two_numbers(l1, l2)
print("Resultant linked list:")
print_linked_list(result)
# Out:
# Resultant linked list:
# 7 -> 0 -> 8

# %%
'''Swap nodes in pairs in a linked list
'''

def swap_pairs(head):
    
    dummy = Node(0)
    dummy.next = head
    prev = dummy

    while head and head.next:
        
        first_node = head
        second_node = head.next

        
        prev.next = second_node
        first_node.next = second_node.next
        second_node.next = first_node

        prev = first_node
        head = first_node.next

    
    return dummy.next

def print_linked_list(node):
    while node:
        print(node.data, end=" -> " if node.next else "\n")
        node = node.next


head = Node(1)
head.next = Node(2)
head.next.next = Node(3)
head.next.next.next = Node(4)


new_head = swap_pairs(head)

# Printing the result
print("Swapped linked list in pairs:")
print_linked_list(new_head)
# Out:
# Swapped linked list in pairs:
# 2 -> 1 -> 4 -> 3

# %%
'''Reverse nodes in a linked list in groups of k
'''

def reverse_k_group(head, k):
    if head is None or k == 1:
        return head
    
    dummy = Node(0)
    dummy.next = head
    current = dummy
    next = dummy
    prev = dummy
    
    count = 0
    while current.next:
        current = current.next
        count += 1
    
    while count >= k:
        current = prev.next
        next = current.next
        for i in range(1, k):
            current.next = next.next
            next.next = prev.next
            prev.next = next
            next = current.next
        prev = current
        count -= k
    
    return dummy.next

def print_linked_list(node):
    while node:
        print(node.data, end=" -> " if node.next else "\n")
        node = node.next


head = Node(1)
head.next = Node(2)
head.next.next = Node(3)
head.next.next.next = Node(4)
head.next.next.next.next = Node(5)
head.next.next.next.next.next = Node(6)
head.next.next.next.next.next.next = Node(7)
head.next.next.next.next.next.next.next = Node(8)
head.next.next.next.next.next.next.next.next = Node(9)

k = 3
new_head = reverse_k_group(head, k)
print("Reversed linked list in groups of 3:")
print_linked_list(new_head)
# Out:
# Reversed linked list in groups of 3:
# 3 -> 2 -> 1 -> 6 -> 5 -> 4 -> 9 -> 8 -> 7

# %%
'''Determine if a linked list is a palindrome.
'''



def is_palindrome(head):
    if head is None or head.next is None:
        return True
    
   
    slow = head
    fast = head
    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next
    
   
    prev = None
    while slow:
        next_node = slow.next
        slow.next = prev
        prev = slow
        slow = next_node
    
    
    left, right = head, prev
    while right:
        if left.data != right.data:
            return False
        left = left.next
        right = right.next
    
   
    return True

def create_linked_list(elements):
    head = Node(elements[0])
    current = head
    for element in elements[1:]:
        current.next = Node(element)
        current = current.next
    return head


def traverse(head):
    current = head
    while current:
        print(current.data, end=" -> ")
        current = current.next
    print("None")

elements = [1, 2, 3, 2, 1]
head = create_linked_list(elements)


print("Original Linked List:")
traverse(head)


result = is_palindrome(head)
print("Above link list is in palindrome :", result)
# Out:
# Original Linked List:
# 1 -> 2 -> 3 -> 2 -> 1 -> None
# Above link list is: True

# %%
'''Rotate a linked list to the right by k places
'''

def rotate_right(head, k):
    if not head or k == 0:
        return head
    
    
    length = 1
    last_node = head
    while last_node.next:
        last_node = last_node.next
        length += 1
    
    
    k = k % length
    if k == 0:
        return head
    
   
    last_node.next = head
    
   
    steps_to_new_head = length - k
    new_tail = head
    for _ in range(steps_to_new_head - 1):
        new_tail = new_tail.next
    
    new_head = new_tail.next
    new_tail.next = None
    
    return new_head


def create_linked_list(elements):
    head = Node(elements[0])
    current = head
    for element in elements[1:]:
        current.next = Node(element)
        current = current.next
    return head


def traverse(head):
    current = head
    while current:
        print(current.data, end=" -> ")
        current = current.next
    print("None")


elements = [1, 2, 3, 4, 5]
k = 2
head = create_linked_list(elements)


print("Original Linked List:")
traverse(head)


rotated_head = rotate_right(head, k)

print(f"Linked List after rotating by {k} places:")
traverse(rotated_head)
# Out:
# Original Linked List:
# 1 -> 2 -> 3 -> 4 -> 5 -> None
# Linked List after rotating by 2 places:
# 4 -> 5 -> 1 -> 2 -> 3 -> None

# %%
'''Flatten a multilevel doubly linked list.
'''


def flatten(head):
    if not head:
        return None
    
   
    current = head
    while current:
        if current.child:
            
            child = flatten(current.child)
            next_node = current.next
            
          
            current.next = child
            child.prev = current
            
           
            tail = child
            while tail.next:
                tail = tail.next
            
           
            tail.next = next_node
            if next_node:
                next_node.prev = tail
            
           
            current.child = None
        
        current = current.next
    
    return head


def print_list(head):
    current = head
    while current:
        print(current.data, end=" -> ")
        current = current.next
    print("None")


head = Node(1)
node2 = Node(2)
node3 = Node(3)
node4 = Node(4)
node5 = Node(5)
node6 = Node(6)
node7 = Node(7)
node8 = Node(8)
node9 = Node(9)

# Set next pointers
head.next = node2
node2.prev = head
node2.next = node3
node3.prev = node2
node3.next = node4
node4.prev = node3
node4.next = node5
node5.prev = node4

# Set child pointers
node3.child = node6
node6.next = node7
node7.prev = node6
node7.child = node8
node8.next = node9
node9.prev = node8

# Flatten the list
print("Original Multilevel Doubly Linked List:")
print_list(head)

flattened_head = flatten(head)

print("Flattened Doubly Linked List:")
print_list(flattened_head)

# %%
'''Rearrange a linked list such that all even positioned nodes are placed at the end
'''
def rearrange_even_positions_to_end(head):
    if not head or not head.next:
        return head

   
    odd = head
    even = head.next
    even_head = even  

    
    while even and even.next:
        odd.next = odd.next.next  
        even.next = even.next.next 
        odd = odd.next
        even = even.next

  
    odd.next = even_head

    return head

def print_list(head):
    temp = head
    while temp:
        print(temp.data, end=" -> ")
        temp = temp.next
    print("None")


head = Node(1)
node2 = Node(2)
node3 = Node(3)
node4 = Node(4)
node5 = Node(5)
node6 = Node(6)

head.next = node2
node2.next = node3
node3.next = node4
node4.next = node5
node5.next = node6

print("Original Linked List:+")
print_list(head)


rearranged_head = rearrange_even_positions_to_end(head)

print("Rearranged Linked List (Even positioned nodes at the end):")
print_list(rearranged_head)

# %%
''' Given a non-negative number represented as a linked list, add one to it.
'''

def rearrange_even_positions_to_end(head):
    if not head or not head.next:
        return head

    odd = head
    even = head.next
    even_head = even  

    
    while even and even.next:
        odd.next = odd.next.next 
        even.next = even.next.next  
        odd = odd.next
        even = even.next

    odd.next = even_head

    return head

def print_list(head):
    temp = head
    while temp:
        print(temp.data, end=" -> ")
        temp = temp.next
    print("None")


head = Node(1)
node2 = Node(2)
node3 = Node(3)
node4 = Node(4)
node5 = Node(5)
node6 = Node(6)

head.next = node2
node2.next = node3
node3.next = node4
node4.next = node5
node5.next = node6

print("Original Linked List:")
print_list(head)


rearranged_head = rearrange_even_positions_to_end(head)

print("Rearranged Linked List (Even positioned nodes at the end):")
print_list(rearranged_head)
# Out:
# Original Linked List:
# 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> None
# Rearranged Linked List (Even positioned nodes at the end):
# 1 -> 3 -> 5 -> 2 -> 4 -> 6 -> None

# %%
'''Given a sorted array and a target value, return the index if the target is found. If not, return the
index where it would be inserted
'''

def search_insert(nums, target):
    left, right = 0, len(nums) - 1
    
    while left <= right:
        mid = (left + right) // 2
        
        if nums[mid] == target:
            return mid
        elif nums[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    
    return left


nums = [1, 3, 5, 6]
target = 5
print(search_insert(nums, target))

target = 2
print(search_insert(nums, target))  

target = 7
print(search_insert(nums, target))

target = 0
print(search_insert(nums, target))
# Out:
# 2
# 1
# 4
# 0

# %%
'''Find the minimum element in a rotated sorted array.
'''
def find_min(nums):
    left, right = 0, len(nums) - 1

    if nums[left] < nums[right]:
        return nums[left]

    while left < right:
        mid = (left + right) // 2

        
        if nums[mid] > nums[right]:
            left = mid + 1
        else:
           
            right = mid
    
   
    return nums[left]

# Example usage:
nums = [4, 5, 6, 7, 0, 1, 2]
print(find_min(nums))  # Output: 0
# Out:
# 0

# %%
'''Search for a target value in a rotated sorted array
'''
def find_min(nums):
    left, right = 0, len(nums) - 1

   
    if nums[left] < nums[right]:
        return nums[left]

    while left < right:
        mid = (left + right) // 2

       
        if nums[mid] > nums[right]:
            left = mid + 1
        else:
            right = mid
   
    return nums[left]

nums = [4, 5, 6, 7, 0, 1, 2]
print(find_min(nums))  # O
# Out:
# 0

# %%
'''Find the peak element in an array. A peak element is greater than its neighbors.
'''
def find_peak_element(nums):
    left, right = 0, len(nums) - 1

    while left < right:
        mid = (left + right) // 2

        
        if nums[mid] < nums[mid + 1]:
            left = mid + 1
        else:
            
            right = mid
    

    return left


nums = [1, 2, 3, 1]
peak_index = find_peak_element(nums)
print(f"The peak element is {nums[peak_index]} at index {peak_index}")

# %%
'''Search for a target value in a rotated sorted array.
'''

def search_rotated_array(nums, target):
    left, right = 0, len(nums) - 1

    while left <= right:
        mid = (left + right) // 2

        
        if nums[mid] == target:
            return mid

      
        if nums[left] <= nums[mid]: 
            if nums[left] <= target < nums[mid]:
                right = mid - 1
            else:
                left = mid + 1
        else:  
            if nums[mid] < target <= nums[right]:
                left = mid + 1
            else:
                right = mid - 1


    return -1


nums = [4, 5, 6, 7, 0, 1, 2]
target = 0
index = search_rotated_array(nums, target)
print(f"Index of the target {target}: {index}")
# Out:
# Index of the target 0: 4

# %%
'''Find the peak element in an array. A peak element is greater than its neighbors
'''

def find_peak_element(nums):
    left, right = 0, len(nums) - 1

    while left < right:
        mid = (left + right) // 2

        if nums[mid] > nums[mid + 1]:
            
            right = mid
        else:
         
            left = mid + 1

    return left


nums1 = [1, 2, 3, 1]
peak_index1 = find_peak_element(nums1)
print(f"Peak element index: {peak_index1}, value: {nums1[peak_index1]}")

nums2 = [1, 2, 1, 3, 5, 6, 4]
peak_index2 = find_peak_element(nums2)
print(f"Peak element index: {peak_index2}, value: {nums2[peak_index2]}")
# Out:
# Peak element index: 2, value: 3
# Peak element index: 5, value: 6

# %%
'''Given a 2D matrix sorted in ascending order in each row, and the first integer of each row is
greater than the last integer of the previous row, determine if a target value is present in the matrix
'''

def searchMatrix(matrix, target):
    if not matrix or not matrix[0]:
        return False
    
    m, n = len(matrix), len(matrix[0])
    left, right = 0, m * n - 1
    
    while left <= right:
        mid = (left + right) // 2
        row = mid // n
        col = mid % n
        
        mid_value = matrix[row][col]
        
        if mid_value == target:
            return True
        elif mid_value < target:
            left = mid + 1
        else:
            right = mid - 1
    
    return False


rows = int(input("Enter the number of rows: "))
cols = int(input("Enter the number of columns: "))

matrix = []
print("Enter the elements row by row:")
for i in range(rows):
    row = list(map(int, input(f"Row {i+1}: ").split()))
    if len(row) != cols:
        print(f"Error: You must enter exactly {cols} elements for row {i+1}.")
        exit(1)
    matrix.append(row)


target = int(input("Enter the target value: "))

found = searchMatrix(matrix, target)

if found:
    print(f"Target {target} is in the matrix.")
else:
    print(f"Target {target} is not in the matrix.")
# Out:
# Enter the number of rows: 3
# Enter the number of columns: 3
# Enter the elements row by row:
# Row 1: 1 2 3
# Row 2: 14 0 36
# Row 3: 7 20 399
# Enter the target value: 20
# Target 20 is in the matrix.

# %%
'''Find Median in Two Sorted Arrays
Problem: Given two sorted arrays, find the median of the combined sorted array.
'''

def findMedianSortedArrays(nums1, nums2):
    
    merged = sorted(nums1 + nums2)
    
   
    n = len(merged)
    if n % 2 == 1:
      
        return merged[n // 2]
    else:
        
        mid1, mid2 = n // 2 - 1, n // 2
        return (merged[mid1] + merged[mid2]) / 2


nums1 = [1, 3]
nums2 = [2]

print(f"Median of the two sorted arrays is: {findMedianSortedArrays(nums1, nums2)}")

nums1 = [1, 2]
nums2 = [3, 4]

print(f"Median of the two sorted arrays is: {findMedianSortedArrays(nums1, nums2)}")
# Out:
# Median of the two sorted arrays is: 2
# Median of the two sorted arrays is: 2.5

# %%
'''Given a sorted character array and a target letter, find the smallest letter in the array that is
greater than the target
'''

def nextGreatestLetter(letters, target):
    left, right = 0, len(letters)
    
    while left < right:
        mid = (left + right) // 2
        if letters[mid] <= target:
            left = mid + 1
        else:
            right = mid
 
    return letters[left % len(letters)]


letters = ['c', 'f', 'j']
target = 'a'

print(f"The smallest letter greater than '{target}' is '{nextGreatestLetter(letters, target)}'")

target = 'c'
print(f"The smallest letter greater than '{target}' is '{nextGreatestLetter(letters, target)}'")

target = 'd'
print(f"The smallest letter greater than '{target}' is '{nextGreatestLetter(letters, target)}'")
# Out:
# The smallest letter greater than 'a' is 'c'
# The smallest letter greater than 'c' is 'f'
# The smallest letter greater than 'd' is 'f'

# %%
'''Given an array with n objects colored red, white, or blue, sort them in-place so that objects of
the same color are adjacent, with the colors in the order red, white, and blue.
'''
def sortColors(nums):
    low, mid, high = 0, 0, len(nums) - 1
    
    while mid <= high:
        if nums[mid] == 0:
            nums[low], nums[mid] = nums[mid], nums[low]
            low += 1
            mid += 1
        elif nums[mid] == 1:
            mid += 1
        else:  # nums[mid] == 2
            nums[high], nums[mid] = nums[mid], nums[high]
            high -= 1

colors = [2, 0, 2, 1, 1, 0]
print("Before sorting:", colors)
sortColors(colors)
print("After sorting:", colors)
# Out:
# Before sorting: [2, 0, 2, 1, 1, 0]
# After sorting: [0, 0, 1, 1, 2, 2]

# %%
'''Find the kth largest element in an unsorted array.
'''
def findKthLargest(nums, k):
    nums.sort(reverse=True)
    return nums[k - 1]

nums = [3, 2, 1, 5, 6, 4]
k = 2
print(f"The {k}th largest element is {findKthLargest(nums, k)}")
# Out:
# The 2th largest element is 5

# %%
'''Given an unsorted array, reorder it in-place such that nums[0] <= nums[1] >= nums[2] <=
nums[3]...
'''

def wiggleSort(nums):
   
    for i in range(len(nums) - 1):
        if (i % 2 == 0 and nums[i] > nums[i + 1]) or (i % 2 == 1 and nums[i] < nums[i + 1]):
            
            nums[i], nums[i + 1] = nums[i + 1], nums[i]


nums = [3, 5, 2, 1, 6, 4]
print("Original array:", nums)
wiggleSort(nums)
print("Wiggled array:", nums)
# Out:
# Original array: [3, 5, 2, 1, 6, 4]
# Wiggled array: [3, 5, 1, 6, 2, 4]

# %%
'''Given an array of integers, calculate the sum of all its elements.
'''

def calculate_sum(arr):
    total = 0
    for num in arr:
        total += num
    return total


array = [1, 2, 3, 4, 5]
total_sum = calculate_sum(array)
print("Sum of elements:", total_sum)
# Out:
# Sum of elements: 15

# %%
'''Find the maximum element in an array of integers.
'''


def find_max(arr):
    if not arr:
        raise ValueError("The array is empty")  
    max_value = arr[0]  
    for num in arr[1:]:  
        if num > max_value:
            max_value = num  
    return max_value


array = [1, 5, 3, 9, 2]
maximum_value = find_max(array)
print("Maximum element:", maximum_value)
# Out:
# Maximum element: 9

# %%
'''Implement linear search to find the index of a target element in an array
'''

def linear_search(arr, target):
  
    for index in range(len(arr)):
        if arr[index] == target:
            return index  
    return -1  


array = [10, 20, 30, 40, 50]
target = 30

index = linear_search(array, target)

if index != -1:
    print(f"Element {target} found at index {index}.")
else:
    print(f"Element {target} not found in the array.")
# Out:
# Element 30 found at index 2.

# %%
''' Calculate the factorial of a given number.
'''
def fact (n):
    fact=1
    for i in range (1,n+1):
        fact=fact*i
        
    print ("Factorial of ", n , "is",fact)
    
num=int (input ("Enter a number to factirial  : "))
fact(num)
# Out:
# Enter a number to factirial  : 5
# Factorial of  5 is 120

# %%
'''Check if a given number is a prime number.
'''

def is_prime(n):
   
    if n <= 1:
        return False  
    if n <= 3:
        return True  

  
    if n % 2 == 0 or n % 3 == 0:
        return False


    i = 5
    while i * i <= n:
        if n % i == 0 or n % (i + 2) == 0:
            return False
        i += 6

    return True

try:
    num = int(input("Enter a number to check if it is prime: "))
    if num < 0:
        print("Negative numbers are not prime.")
    else:
        if is_prime(num):
            print(f"{num} is a prime number.")
        else:
            print(f"{num} is not a prime number.")
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter a number to check if it is prime: 2
# 2 is a prime number.

# %%
'''Generate the Fibonacci series up to a given number n.
'''

def GenerateFibonacci  (n):
    fibo_series = []
    a,b=0,1 
    while a <n:
        fibo_series.append (a)
        a,b=b,a+b
       
    return fibo_series
        
num = int(input("Enter the upper limit for the Fibonacci series: "))
fibo_series=GenerateFibonacci(num)
print("Fibonacci series up to", num, ":", fibo_series)
# Out:
# Enter the upper limit for the Fibonacci series: 17
# Fibonacci series up to 17 : [0, 1, 1, 2, 3, 5, 8, 13]

# %%
""" Calculate the power of a number using recursion.
"""


def power(base, exponent):
   
   
    if exponent == 0:
        return 1
    
    else:
        return base * power(base, exponent - 1)


base = int(input("Enter the base number: "))
exponent = int(input("Enter the exponent: "))


result = power(base, exponent)
print(f"{base} raised to the power of {exponent} is {result}")
# Out:
# Enter the base number: 2
# Enter the exponent: 8
# 2 raised to the power of 8 is 256

# %%
'''Reverse a given string
'''
def reverse_string(s):
    
    return s[::-1]


input_string = input("Enter a string to reverse: ")


reversed_string = reverse_string(input_string)
print("Reversed string:", reversed_string)
