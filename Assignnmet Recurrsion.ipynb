# %% [markdown]
# # Find the value of T (2) for the recurrence relation T (n) =T(n-1)+ 12 n  given that T(0)=5
#
#
# as T(0)=5 and T (n) =T(n-1)+ 12 n
#
# for T(1)
#  T(1)= T(1-1)+12(1)
#      = T(0)+12
#      =  5+12
#      =  17
#
# for T(2)
#  T(2) = T(2-1)+12 (2)
#       = T (1) + 12 * 2
#       = 17+24
#       = 41

# %% [markdown]
# # solve using substitution method

# %% [markdown]
# a) T(n)= T(n-1)+c
#
# for T(n-1)
# = T(n-1)+c
# = T(n-1)+c
#
#
# for T(n-2)
# =T(n-2-1)+c
# =T(n-3)+c
#
#
#
# T(n)=T(n-1)+c
#      we know the value of T (n-1) = T(n-1)+c
#     =T(n-2)+c+c
#     =T(n-2)+2c
#      we know the value of T (n-2) = T(n-2)+c
#     =T(n-2)+c+c
#     =T(n-2)+2c
#         .
#         .
#         .
#         .
# T(n)=T(n-k)+kc
#
# When k=n
# T(n)=T(n-n)+nc
# T(n)=T0+nc

# %% [markdown]
# b) T(n)=2T(n/2)+n
#
# T(n)= 2T(n/2)+n
#
#
# for T(n/2)
# = 2T(n/2/2)+n/2
# = 2T(n/4)+n/2
#
# for T(n/4)
# = 2T(n/4/2)+n/4
# = 2T(n/8)+n/4
#
# now,
# T(n)= 2T(n/2)+n
#
# putting value of T(n/2)= 2T(n/4)+n
#
# =2[2T(n/4)+n/2]+n
# =2.2T(n/4)+n+n
# =4T(n/4)+2n
#
# putting value of T(n/4)= 2T(n/8)+n/4
# =4[2T(n/8)+n/4]+2n
# =8T(n/8)+n+2n
# =8T(n/8)+3n
#    .
#    .
#    .
# T(n)= 2^k T (n/2^k) + kn
#
# n/2^k=1
# n=2^k
# k=log n
#
# T(n)=n T(1)+ n log n

# %% [markdown]
#  c) T(n)=2T(n/2)+c
#
#  for T(n/2)
# = 2T(n/2/2)+c
# = 2T(n/4)+c
#
#
# for T(n/4)
# = 2T(n/4/2)+c
# = 2T(n/8)+c
# = 2T(n/8)+c
#
#
# T(n)=2T(n/2)+c
# puttting value of T(n/2)= 2T(n/4)+c
# = 2T(2T(n/4)+c)+c
# = 4T(n/4)+3c
# putting value of T(n/4)= 2T(n/8)+c
#
# = 4[2T(n/8)+c]+3c
# =  8T(n/8)+7c
#      .
#      .
#      .
#
# T(n)= 2^k T (n/2^k) + (2^k -1)c
#
# n/2^k=1
# n=2^k
# k=log n
#
# T(n)= n T(1) + (n -1)c

# %% [markdown]
# d)T(n)= T(n/2)+c
#
#
# for T(n/2)
# =T(n/2/2)+c
# =T(n/4)+c
#
# for T(n/4)
# =T(n/4/2)+c
# =T(n/8)+c
#
#
# T(n)=2T(n/2)+c
# puttting value of T(n/2)= T(n/4)+c
# = (T(n/4)+c)+c
# =  T(n/4)+2c
#
# putting value of T(n/4)= T(n/8)+c
# = T(n/8)+c+2c
# = T(n/8)+3c
#      .
#      .
#      .
# T(n)= T(n/2^k) + kc
# n/2^k=1
# n=2^k
# k=log n
#
# T(n)=T(1)+c log n

# %% [markdown]
# # Solve it using the recursive tree approach

# %% [markdown]
#  a) T(n)=2T(n-1)+1
#
#
#             T(n)
#             .  .   .
#            .    .    .
#           .      .     .
#      T(n-1)   T(n-1)    1      = 2^0
#        .        .        .
#       .          .         .
#      .            .         .
#   T(n-2)        T(n-2)       1  =2^1
#    .              .          .
#    .              .          .
#  T(0)           T(0)        T(0) =2^k
#
#
#  2^0 + 2^1+2^2+....+2^k
#
#  as, n-k=0
#  n=k
#
#  using sum gp formula=a(r^n -1)//(r-1)
#
#  here,
#    = 2^0 (2^n -1)//2-1
#    = 2 ^ n+1 -1
# T(c) =2^n +2^n
#
# T(c) =o(2^n)

# %% [markdown]
# b) T(n)=2T(n/2)+n
#
#
#               T(n)
#             .     .
#            .        .
#           .           .
#      T(n/2)          T(n/2)      n
#        .                 .
#       .                    .
#      .                      .
#   T(n/2^2)                  T(n/2^2)    n
#    .                        .
#    .                        .
#  T(n/2^k)                      T(n/2^k)   kn
#
#
#  n/2^k=1
#  n=2^k
#  take log on both side
#  k=log n
#
#  T(c)=nlogn
